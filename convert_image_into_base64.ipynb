# %%
# Import the base64 encoding library.
# https://cloud.google.com/vertex-ai/docs/general/base64#windows
import base64

# Pass the image data to an encoding function.
def encode_image(image):
    with open(image, "rb") as image_file:
        encoded_string = base64.b64encode(image_file.read())
    return encoded_string

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
encode_image("/content/drive/MyDrive/imagery/dog_test.jpg")
# Out:
# b'...'

# %%
encode_image("/content/drive/MyDrive/imagery/Capture.JPG")
# Out:
# b'...'

# %%
encode_image("/content/drive/MyDrive/imagery/kitchen_rajeshPNG.PNG")
# Out:
# b'...'

# %%
encode_image("/content/drive/MyDrive/imagery/second_cat.JPG")
# Out:
# b'...'

# %%
encode_image("/content/drive/MyDrive/imagery/spaceship.JPG")
# Out:
# b'...'
